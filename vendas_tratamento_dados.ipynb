# %% [markdown]
# <a href="https://colab.research.google.com/github/Clarice-Satiko-Aoto/Analise_dados_b/blob/main/vendas_tratamento_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carregando os dados

# %%
cat_produto = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBCategoriaProduto.csv') #
cliente = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBCliente.csv') #
depara_cliente_vendedor = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBClientesVendedores.csv')
geografia = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBGeografia.csv') #
itens_venda = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBItensVendas.csv')
produto = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBProduto.csv') #
regioes = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBRegioesBrasil.csv') #
supervisor = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBSupervisor.csv') #
vendas = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBVendas.csv')
vendedor = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/PBVendedor.csv') #

# %% [markdown]
# ## Análise Exploratória dos Dados

# %% [markdown]
# ### Transformando os dados

# %%
#Renomeando a coluna do cat_produto
cat_produto.rename(columns={'descricao': 'categoria'}, inplace=True)

# %%
vendedor.rename(columns={'descricao': 'nome_vendedor'}, inplace=True)
supervisor.rename(columns={'descricao': 'nome_supervisor', 'gerente_descricao': 'nome_gerente'}, inplace=True)

# %%
#renomeando a coluna id
vendas.rename(columns={'id': 'vendas_id',
                       'valor_bruto': 'nf_valor_bruto',
                       'valor_venda': 'nf_valor_venda'}, inplace=True
              )

# %%
#Transformando os tipos dos dados para podermos calcular os valores
vendas['nf_desconto'] = vendas['nf_desconto'].str.replace(',', '.', regex=True)
vendas['nf_desconto'] = pd.to_numeric(vendas['nf_desconto'], errors='coerce')

vendas['nf_valor_venda'] = vendas['nf_valor_venda'].str.replace(',', '.', regex=True)
vendas['nf_valor_venda'] = pd.to_numeric(vendas['nf_valor_venda'], errors='coerce')

# %%
#renomeando a coluna id
itens_venda.rename(columns={'id': 'itens_venda_id'}, inplace=True)

# %%
#juntando cat_produto e produto
dProduto = produto.merge(cat_produto, left_on='categoria_id', right_on='id', how='inner')
dProduto = dProduto.drop('id_y', axis=1)
dProduto.rename(columns={'id_x': 'produto_id'}, inplace=True)
dProduto.head()
# Out:
#    produto_id  categoria_id       descricao tamanho  custoUnitario  \
# 0           1             1      Casual Day       M             90
# 1           2             1      Casual Day       P             90
# 2           3             1      Casual Day       G             90
# 3           4             1  Psyco Universe      GG             60
# 4           5             1  Psyco Universe       P             60
#
#      categoria
# 0  Manga Longa
# 1  Manga Longa
# 2  Manga Longa
# 3  Manga Longa
# 4  Manga Longa

# %%
#juntando cliente, geografia e regioes
dCliente = cliente.merge(geografia, left_on='geografia_id', right_on='id', how='inner')
dCliente = dCliente.merge(regioes, left_on='uf', right_on='UF')
dCliente = dCliente.drop(['id_y', 'geografia_id', 'uf'], axis=1)
dCliente.rename(columns={'id_x': 'cliente_id', 'descricao':'cliente'}, inplace=True)
dCliente.head()
# Out:
#    cliente_id                        cliente  cidade      estado  UF    Regiao
# 0           1                      Nolan Inc  Recife  Pernambuco  PE  Região 2
# 1          75                 Blick-Dietrich  Recife  Pernambuco  PE  Região 2
# 2         144  Gleason, Legros and Jaskolski  Recife  Pernambuco  PE  Região 2
# 3         154                  Beier-Gerlach  Recife  Pernambuco  PE  Região 2
# 4         157                Howell and Sons  Recife  Pernambuco  PE  Região 2

# %%
#fazendo o de para dcliente e vendedor
dCliente = dCliente.merge(depara_cliente_vendedor, left_on='cliente_id', right_on='cliente_id')
dCliente.head()
# Out:
#    cliente_id                        cliente  cidade      estado  UF  \
# 0           1                      Nolan Inc  Recife  Pernambuco  PE
# 1          75                 Blick-Dietrich  Recife  Pernambuco  PE
# 2         144  Gleason, Legros and Jaskolski  Recife  Pernambuco  PE
# 3         154                  Beier-Gerlach  Recife  Pernambuco  PE
# 4         157                Howell and Sons  Recife  Pernambuco  PE
#
#      Regiao  vendedor_id
# 0  Região 2            1
# 1  Região 2            4
# 2  Região 2            4
# 3  Região 2            4
# 4  Região 2            7

# %%
#criando o df dHierarquia (supervisor, gerente e vendedor)
dHierarquia = supervisor.merge(vendedor, left_on='id', right_on='supervisor_id')
dHierarquia = dHierarquia.drop(columns=['supervisor_id'])
dHierarquia.rename(columns={'id_x': 'supervisor_id','id_y': 'vendedor_id'}, inplace=True)
dHierarquia
# Out:
#     supervisor_id nome_supervisor  gerente_id     nome_gerente  vendedor_id  \
# 0               1  Fernando Silva           1    Victor Castro           12
# 1               2     Emily Rocha           1    Victor Castro            1
# 2               2     Emily Rocha           1    Victor Castro            4
# 3               2     Emily Rocha           1    Victor Castro           11
# 4               3    Diego Araujo           1    Victor Castro            6
# 5               3    Diego Araujo           1    Victor Castro            7
# 6               4  Diogo Carvalho           2  Gabriel Azevedo            2
# 7               4  Diogo Carvalho           2  Gabriel Azevedo            5
# 8               4  Diogo Carvalho           2  Gabriel Azevedo            8
# 9               5   Sofia Ribeiro           2  Gabriel Azevedo            3
# 10              5   Sofia Ribeiro           2  Gabriel Azevedo            9
# 11              5   Sofia Ribeiro           2  Gabriel Azevedo           10
#
#         nome_vendedor
# 0      Flávio Roberto
# 1      Augusto Bradão
# 2    Isabella Machado
# 3         Bruna Maria
# 4    Rodrigo Santiago
# 5   Flávia Alessandra
# 6       Roberto Silva
# 7       Estevan Souza
# 8          Julio Lima
# 9    Felipe Gonçalves
# 10       Mateus Costa
# 11  Fernanda Oliveira

# %%
#juntando as informações de hierarquia com as do cliente
dCliente = dCliente.merge(dHierarquia, left_on='vendedor_id', right_on='vendedor_id')
dCliente.head()
# Out:
#    cliente_id                       cliente    cidade      estado  UF  \
# 0           1                     Nolan Inc    Recife  Pernambuco  PE
# 1         206                    Ferry-Kris    Recife  Pernambuco  PE
# 2         303                Jones-Schmeler    Recife  Pernambuco  PE
# 3         612                  Botsford Inc    Recife  Pernambuco  PE
# 4         168  Emmerich, Gaylord and Harber  São Luís    Maranhao  MA
#
#      Regiao  vendedor_id  supervisor_id nome_supervisor  gerente_id  \
# 0  Região 2            1              2     Emily Rocha           1
# 1  Região 2            1              2     Emily Rocha           1
# 2  Região 2            1              2     Emily Rocha           1
# 3  Região 2            1              2     Emily Rocha           1
# 4  Região 2            1              2     Emily Rocha           1
#
#     nome_gerente   nome_vendedor
# 0  Victor Castro  Augusto Bradão
# 1  Victor Castro  Augusto Bradão
# 2  Victor Castro  Augusto Bradão
# 3  Victor Castro  Augusto Bradão
# 4  Victor Castro  Augusto Bradão

# %% [markdown]
# Trabalhando com as tabelas vendas e itens_venda

# %%
#juntando as informações de vendas e itens-venda
nfe_vendas = vendas.merge(itens_venda, on='vendas_id')
nfe_vendas.head()
# Out:
#    vendas_id       data      nfe  cliente_id  nf_desconto  nf_valor_bruto  \
# 0          1  2/16/2021  SO43660         614         24.9             265
# 1          1  2/16/2021  SO43660         614         24.9             265
# 2          2  2/16/2021  SO43661         338        126.3            2323
# 3          2  2/16/2021  SO43661         338        126.3            2323
# 4          2  2/16/2021  SO43661         338        126.3            2323
#
#    nf_valor_venda  itens_venda_id  produto_id  item_quantidade  \
# 0           240.1              13          43                1
# 1           240.1              14          49                1
# 2          2196.7              27          30                1
# 3          2196.7              18          15                1
# 4          2196.7              21          56                1
#
#    valor_unitario  valor_bruto
# 0             112          112
# 1             153          153
# 2             144          144
# 3             167          167
# 4             178          178

# %%
#calculando a coluna do valor do desconto item a item
valor_unitario = nfe_vendas['valor_unitario']
valor_bruto = nfe_vendas['nf_valor_bruto']
desc_nf = nfe_vendas['nf_desconto']


nfe_vendas['valor_desconto'] = round(valor_unitario/valor_bruto * desc_nf ,2)
nfe_vendas.head()
# Out:
#    vendas_id       data      nfe  cliente_id  nf_desconto  nf_valor_bruto  \
# 0          1  2/16/2021  SO43660         614         24.9             265
# 1          1  2/16/2021  SO43660         614         24.9             265
# 2          2  2/16/2021  SO43661         338        126.3            2323
# 3          2  2/16/2021  SO43661         338        126.3            2323
# 4          2  2/16/2021  SO43661         338        126.3            2323
#
#    nf_valor_venda  itens_venda_id  produto_id  item_quantidade  \
# 0           240.1              13          43                1
# 1           240.1              14          49                1
# 2          2196.7              27          30                1
# 3          2196.7              18          15                1
# 4          2196.7              21          56                1
#
#    valor_unitario  valor_bruto  valor_desconto
# 0             112          112           10.52
# 1             153          153           14.38
# 2             144          144            7.83
# 3             167          167            9.08
# 4             178          178            9.68

# %%
#juntando nfe_vendas e dClientes
dCliente.head()
# Out:
#    cliente_id                       cliente    cidade      estado  UF  \
# 0           1                     Nolan Inc    Recife  Pernambuco  PE
# 1         206                    Ferry-Kris    Recife  Pernambuco  PE
# 2         303                Jones-Schmeler    Recife  Pernambuco  PE
# 3         612                  Botsford Inc    Recife  Pernambuco  PE
# 4         168  Emmerich, Gaylord and Harber  São Luís    Maranhao  MA
#
#      Regiao  vendedor_id  supervisor_id nome_supervisor  gerente_id  \
# 0  Região 2            1              2     Emily Rocha           1
# 1  Região 2            1              2     Emily Rocha           1
# 2  Região 2            1              2     Emily Rocha           1
# 3  Região 2            1              2     Emily Rocha           1
# 4  Região 2            1              2     Emily Rocha           1
#
#     nome_gerente   nome_vendedor
# 0  Victor Castro  Augusto Bradão
# 1  Victor Castro  Augusto Bradão
# 2  Victor Castro  Augusto Bradão
# 3  Victor Castro  Augusto Bradão
# 4  Victor Castro  Augusto Bradão

# %%
movimentacao_vendas  = nfe_vendas.merge(dCliente, on='cliente_id')
movimentacao_vendas.head()
# Out:
#    vendas_id       data      nfe  cliente_id  nf_desconto  nf_valor_bruto  \
# 0          1  2/16/2021  SO43660         614         24.9             265
# 1          1  2/16/2021  SO43660         614         24.9             265
# 2        118  3/10/2021  SO44078         614        113.4            1172
# 3        118  3/10/2021  SO44078         614        113.4            1172
# 4        118  3/10/2021  SO44078         614        113.4            1172
#
#    nf_valor_venda  itens_venda_id  produto_id  item_quantidade  ...    cidade  \
# 0           240.1              13          43                1  ...  Salvador
# 1           240.1              14          49                1  ...  Salvador
# 2          1058.6            1162          36                2  ...  Salvador
# 3          1058.6            1163           2                1  ...  Salvador
# 4          1058.6            1165          15                1  ...  Salvador
#
#    estado  UF    Regiao vendedor_id supervisor_id nome_supervisor gerente_id  \
# 0   Bahia  BA  Região 2           4             2     Emily Rocha          1
# 1   Bahia  BA  Região 2           4             2     Emily Rocha          1
# 2   Bahia  BA  Região 2           4             2     Emily Rocha          1
# 3   Bahia  BA  Região 2           4             2     Emily Rocha          1
# 4   Bahia  BA  Região 2           4             2     Emily Rocha          1
#
#     nome_gerente     nome_vendedor
# 0  Victor Castro  Isabella Machado
# 1  Victor Castro  Isabella Machado
# 2  Victor Castro  Isabella Machado
# 3  Victor Castro  Isabella Machado
# 4  Victor Castro  Isabella Machado
#
# [5 rows x 24 columns]

# %%
#consolidando os dados com a tabela Produtos
df = movimentacao_vendas.merge(dProduto, on='produto_id')
df.head()
# Out:
#    vendas_id       data      nfe  cliente_id  nf_desconto  nf_valor_bruto  \
# 0          1  2/16/2021  SO43660         614        24.90             265
# 1       3020  6/10/2023  SO87451          50       398.45            5758
# 2        993  6/24/2021  SO46324         259        62.80            1014
# 3          7  2/17/2021  SO43665         347       112.95            1711
# 4       2443  8/15/2022  SO51151         318       545.55            8066
#
#    nf_valor_venda  itens_venda_id  produto_id  item_quantidade  ...  \
# 0          240.10              13          43                1  ...
# 1         5359.55           46451          43                1  ...
# 2          951.20            7650          43                1  ...
# 3         1598.05              61          43                1  ...
# 4         7520.45           31879          43                1  ...
#
#    supervisor_id  nome_supervisor  gerente_id     nome_gerente  \
# 0              2      Emily Rocha           1    Victor Castro
# 1              5    Sofia Ribeiro           2  Gabriel Azevedo
# 2              5    Sofia Ribeiro           2  Gabriel Azevedo
# 3              5    Sofia Ribeiro           2  Gabriel Azevedo
# 4              5    Sofia Ribeiro           2  Gabriel Azevedo
#
#        nome_vendedor categoria_id descricao tamanho  custoUnitario  \
# 0   Isabella Machado            2   Paeonia       M             75
# 1  Fernanda Oliveira            2   Paeonia       M             75
# 2  Fernanda Oliveira            2   Paeonia       M             75
# 3   Felipe Gonçalves            2   Paeonia       M             75
# 4  Fernanda Oliveira            2   Paeonia       M             75
#
#      categoria
# 0  Manga Curta
# 1  Manga Curta
# 2  Manga Curta
# 3  Manga Curta
# 4  Manga Curta
#
# [5 rows x 29 columns]

# %%
#calculando a margem de lucro unitaria do produto
df['margem_lucro_unit'] = df['valor_unitario'] - df['custoUnitario']

# %%
#salvando o arquivo
df.to_csv('/content/drive/MyDrive/Colab Notebooks/vendas/vendas.csv', index=False)
